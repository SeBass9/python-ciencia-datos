# %% [markdown]
# <a href="https://colab.research.google.com/github/SeBass9/python-ciencia-datos/blob/main/Comentarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Este es un comentario en python
print("Hola mundo!")
# Out:
# Hola mundo!

# %%
"""
Este
comentario
es en
Colab
"""
print("HOLA")
# Out:
# HOLA

# %% [markdown]
# Este comentario es en Colab

# %% [markdown]
# ![94469830_10222582962466571_224389569947107328_n.jpg](data:image/jpeg;base64,...)
